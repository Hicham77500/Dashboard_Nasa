# %%
### ✅ **Plan détaillé et Répartition du travail**
🚀 **Projet : Dashboard des Astéroïdes proches de la Terre**  
📆 **Deadline : Vendredi matin (fonctionnel)**  
👨‍💻 **Équipe : 3 personnes (1 back-end, 2 fullstack)**  

---

## **1️⃣ Organisation du projet**
📌 **Stack :**  
- **Backend :** Flask + PyMongo (API NASA, stockage MongoDB, requêtes d’agrégation)  
- **Base de données :** MongoDB (historique des astéroïdes)  
- **Frontend :** Bootstrap + cartes interactives  
- **JS (optionnel) :** Alpine.js ou Vue.js (alertes dynamiques)  

📌 **Répartition des rôles :**  
👤 **Back-End (1 personne)**
- Connexion à l’API NASA.
- Stockage des données en MongoDB.
- Implémentation des requêtes d’agrégation.
- Création des endpoints Flask pour le front.  

👥 **Fullstack 1 (Front + API)**
- Intégration du front avec Flask (Bootstrap).
- Affichage des données des astéroïdes.
- Mise en place de la carte interactive.

👥 **Fullstack 2 (JS + Filtres)**
- Ajout des **filtres dynamiques** (taille, vitesse, dangerosité).
- Intégration des **alertes en cas d’astéroïde dangereux**.
- Optionnel : Dynamisation avec Alpine.js / Vue.js.

---

## **2️⃣ Plan de développement par jour**
### 📅 **Jour 1 (Aujourd’hui) - Setup & API**
✅ **Back-End :**
- Initialisation de Flask.
- Connexion avec l’API NASA (test avec `requests`).
- Stockage des données dans MongoDB.

✅ **Fullstack 1 :**
- Création du design avec **Bootstrap** (interface de base).
- Page de base avec un tableau pour afficher les astéroïdes.

✅ **Fullstack 2 :**
- Setup du **JS (Alpine.js ou Vue.js)**
- Tests des premiers filtres interactifs.

---

### 📅 **Jour 2 (Jeudi) - Intégration & Affichage**
✅ **Back-End :**
- Création des **endpoints Flask** (récupération MongoDB).
- Implémentation des **requêtes d’agrégation** (taille moyenne, max, vitesse...).

✅ **Fullstack 1 :**
- Affichage des **cartes interactives** avec les astéroïdes.
- Connexion avec les endpoints Flask.

✅ **Fullstack 2 :**
- Intégration des **alertes** en fonction des seuils définis.
- Finalisation des **filtres dynamiques**.

---

### 📅 **Jour 3 (Vendredi matin) - Debug & Finalisation**
✅ **Tout le monde :**
- Tests et corrections de bugs.
- Optimisation des requêtes MongoDB.
- Améliorations visuelles.

---

## **3️⃣ Difficulté des requêtes d’agrégation**
📌 **Les requêtes MongoDB en agrégation peuvent être complexes si :**
- Vous voulez **calculer en temps réel** (ce qui implique du **polling** ou **WebSockets**).
- Vous traitez **beaucoup de données** (nécessite des index).

**Solution simple et rapide :**
- **Stocker les données toutes les X minutes** via un script cron.
- Faire une **mise à jour périodique** (ex. toutes les 30 min) au lieu d’un vrai **temps réel**.

💡 **Si vous voulez éviter la complexité**, on peut :
- Prendre les **dernières données** de l’API NASA et les afficher directement.
- Utiliser **des agrégations simples** (`$avg`, `$max`, `$sort`) pour éviter trop de charge.

---

## **4️⃣ Besoin d’un starter-pack Flask + MongoDB ?**
Si vous voulez, je peux **générer un projet Flask prêt à l’emploi** avec :
✅ **Connexion API NASA**  
✅ **Stockage MongoDB**  
✅ **Structure Flask avec endpoints**  
✅ **Base HTML Bootstrap prête**
